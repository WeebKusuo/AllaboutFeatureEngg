# %% [markdown]
# Handling Outliers Using Python

# %% [markdown]
# 5 number Summary And Box PLot

# %%
##minimum,maximum,mmedian,q1,q3,iqr

# %%
import numpy as np

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
minimum,q1,median,q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum,q1,median,q3,maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
# IQR_--- inter quatile range q3-q1
IQR=q3-q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence=q1-1.5*(IQR)
higher_fence=q3+1.5*(IQR)

# %%
lower_fence,higher_fence
# Out:
# (np.float64(1.5), np.float64(141.5))

# %%
# now any value that is lower than 1.5 and 
# greater than 141.5 will be considered as an outlier

# %%
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[0.5,1.2,0.254,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,170,180]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
